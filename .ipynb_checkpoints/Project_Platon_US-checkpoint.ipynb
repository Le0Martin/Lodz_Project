# %% [markdown]
# Establishing connection to MongoDB server running on specified IP address and port

# %%
from pymongo import MongoClient  # Import MongoClient class
from datetime import datetime  # Import datetime 

# Defining get_db_connection function which receives ip, port and database name (db_name)
def get_db_connection(ip, port, db_name):
    try:
        # Create an instance of the class MongoClient. 
        # This initiates a connection to the MongoDB server on the specified IP and port
        client = MongoClient(ip, port)

        # Once the connection is established, we can access the specific database with the name 'db_name'
        db = client[db_name]

        # The function returns the 'db' object that allows interaction with the database
        return db

    # This block will be executed if there is an exception during the 'try' execution
    except Exception as e:
        # Prints an error message with the exception description
        print(f"Error connecting to database: {e}")

        # Returns None if the connection failed
        return None

# establishing connection to the MongoDB server
db = get_db_connection('localhost', 27017, 'myDatabase')

# If the function returned None, then the connection failed
if db is None:
    print("Database connection failed!")

else:
    print("Database connection successful!")
# Out:
# Database connection successful!

# %% [markdown]
# This set of functions filters data in a MongoDB collection according to different criteria.

# %%
from pymongo import MongoClient

# Function to filter documents based on fields "sequence.channel" and "sequence.service"
def filter_by_channel_and_service(db, collection_name, channel, service):
    query = {"sequence.channel": channel, "sequence.service": service}
    print(f"Query: {query}")
    # Executes the query on the specified collection
    result = db[collection_name].find(query)
    return result

# Function to get the timestamp documents 
def get_time_range(db, collection):
    # Searches for the first document based on the "sequence.timestamp" field in ascending order
    first_document = db[collection].find().sort("sequence.timestamp", 1).limit(1)
    # Searches for the last document based on the "sequence.timestamp" field in descending order
    last_document = db[collection].find().sort("sequence.timestamp", -1).limit(1)

    # Extract timestamp from first and last document
    start_time = first_document[0]["sequence"]["timestamp"]
    end_time = last_document[0]["sequence"]["timestamp"]

    return start_time, end_time

# Function to filter documents based on a time range
def filter_by_date(db, collection, start_time, end_time):
    try:
        # Build the search query
        query = {
            "sequence.timestamp": {
                "$gte": start_time,
                "$lte": end_time
            }
        }
        count = db[collection].count_documents(query)
        print(f"Count: {count}")
        cursor = db[collection].find(query)
        return cursor
    
    except Exception as e:
        print(f"Erro: {e}")
        return None

# Function to filter documents "sequence.schema"
def filter_by_schema(db, collection_name, schema):
    query = {"sequence.schema": schema}
    result = db[collection_name].find(query)
    return result

# Function to filter documents "payload.timeout"
def filter_by_timeout(db, collection_name, timeout):
    query = {"payload.timeout": timeout}
    result = db[collection_name].find(query)
    return result

# Function to filter documents "payload.publishes"
def filter_by_publishes(db, collection_name, publishes):
    query = {"payload.publishes": publishes}
    result = db[collection_name].find(query)
    return result

# Function to filter documents "payload.subscribes"
def filter_by_subscribes(db, collection_name, subscribes):
    query = {"payload.subscribes": subscribes}
    result = db[collection_name].find(query)
    return result

# Function to filter documents "payload.next_alive_interval"
def filter_by_next_alive_interval(db, collection_name, next_alive_interval):
    # If next_alive_interval is None, returns all documents
    if next_alive_interval is None:
        return db[collection_name].find() 
    else:
        query = {"payload.next_alive_interval": next_alive_interval}
        result = db[collection_name].find(query)
        return result

# %% [markdown]
# This code uses the get_time_range function to get the start time (start_time) and end time (end_time) of the documents in the "myCollection" collection of the MongoDB database.
#
# These times are based on the "sequence.timestamp" field of the documents in the collection. The get_time_range function searches for the oldest  and the newest document and returns their respective times.

# %%
start_time, end_time = get_time_range(db, "myCollection")
print(f"Start time: {start_time}")
print(f"End time: {end_time}")
# Out:
# Start time: 2021-03-29T14:13:34.249+02:00
# End time: 2021-07-12T08:38:44.344+0200

# %% [markdown]
# Filtering by date

# %%
start_time = "2021-03-29T14:13:34.249+02:00"
end_time = "2021-03-29T14:14:01.285+02:00"
cursor = filter_by_date(db, "myCollection", start_time, end_time)
if cursor:
    for document in cursor:
        print(document)
# Out:
# Count: 10
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fde6'), 'sequence': {'timestamp': '2021-03-29T14:13:34.249+02:00', 'number': 2, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fde7'), 'sequence': {'timestamp': '2021-03-29T14:13:37.253+02:00', 'number': 3, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fde8'), 'sequence': {'timestamp': '2021-03-29T14:13:40.257+02:00', 'number': 4, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fde9'), 'sequence': {'timestamp': '2021-03-29T14:13:43.261+02:00', 'number': 5, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fdea'), 'sequence': {'timestamp': '2021-03-29T14:13:46.265+02:00', 'number': 6, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fdeb'), 'sequence': {'timestamp': '2021-03-29T14:13:49.268+02:00', 'number': 7, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fdec'), 'sequence': {'timestamp': '2021-03-29T14:13:52.273+02:00', 'number': 8, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fded'), 'sequence': {'timestamp': '2021-03-29T14:13:55.277+02:00', 'number': 9, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fdee'), 'sequence': {'timestamp': '2021-03-29T14:13:58.281+02:00', 'number': 10, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fdef'), 'sequence': {'timestamp': '2021-03-29T14:14:01.285+02:00', 'number': 11, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}

# %%
# Defining test parameters
collection_name = "myCollection"
channel = "status"
service = "mediator"

cursor = filter_by_channel_and_service(db, collection_name, channel, service)

# Checking if the function returned a cursor
if cursor is not None:
    for document in cursor:
        print(document)
else:
    print("No documents found.")
# Out:
# Query: {'sequence.channel': 'status', 'sequence.service': 'mediator'}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fde6'), 'sequence': {'timestamp': '2021-03-29T14:13:34.249+02:00', 'number': 2, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fde7'), 'sequence': {'timestamp': '2021-03-29T14:13:37.253+02:00', 'number': 3, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fde8'), 'sequence': {'timestamp': '2021-03-29T14:13:40.257+02:00', 'number': 4, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fde9'), 'sequence': {'timestamp': '2021-03-29T14:13:43.261+02:00', 'number': 5, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fdea'), 'sequence': {'timestamp': '2021-03-29T14:13:46.265+02:00', 'number': 6, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fdeb'), 'sequence': {'timestamp': '2021-03-29T14:13:49.268+02:00', 'number': 7, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fdec'), 'sequence': {'timestamp': '2021-03-29T14:13:52.273+02:00', 'number': 8, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fded'), 'sequence': {'timestamp': '2021-03-29T14:13:55.277+02:00', 'number': 9, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fdee'), 'sequence': {'timestamp': '2021-03-29T14:13:58.281+02:00', 'number': 10, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fdef'), 'sequence': {'timestamp': '2021-03-29T14:14:01.285+02:00', 'number': 11, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fdf0'), 'sequence': {'timestamp': '2021-03-29T14:14:04.290+02:00', 'number': 12, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fdf1'), 'sequence': {'timestamp': '2021-03-29T14:14:07.294+02:00', 'number': 13, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fdf2'), 'sequence': {'timestamp': '2021-03-29T14:14:10.297+02:00', 'number': 14, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fdf3'), 'sequence': {'timestamp': '2021-03-29T14:14:13.303+02:00', 'number': 15, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fdf4'), 'sequence': {'timestamp': '2021-03-29T14:14:16.307+02:00', 'number': 16, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fd
 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe39'), 'sequence': {'timestamp': '2021-03-29T14:17:43.573+02:00', 'number': 85, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe3a'), 'sequence': {'timestamp': '2021-03-29T14:17:46.577+02:00', 'number': 86, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe3b'), 'sequence': {'timestamp': '2021-03-29T14:17:49.580+02:00', 'number': 87, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe3c'), 'sequence': {'timestamp': '2021-03-29T14:17:52.586+02:00', 'number': 88, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe3d'), 'sequence': {'timestamp': '2021-03-29T14:17:55.590+02:00', 'number': 89, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe3e'), 'sequence': {'timestamp': '2021-03-29T14:17:58.593+02:00', 'number': 90, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe3f'), 'sequence': {'timestamp': '2021-03-29T14:18:01.597+02:00', 'number': 91, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe40'), 'sequence': {'timestamp': '2021-03-29T14:18:04.601+02:00', 'number': 92, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe41'), 'sequence': {'timestamp': '2021-03-29T14:18:07.605+02:00', 'number': 93, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe42'), 'sequence': {'timestamp': '2021-03-29T14:18:10.609+02:00', 'number': 94, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe43'), 'sequence': {'timestamp': '2021-03-29T14:18:13.614+02:00', 'number': 95, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe44'), 'sequence': {'timestamp': '2021-03-29T14:18:16.618+02:00', 'number': 96, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe45'), 'sequence': {'timestamp': '2021-03-29T14:18:19.622+02:00', 'number': 97, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe46'), 'sequence': {'timestamp': '2021-03-29T14:18:22.625+02:00', 'number': 98, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe47'), 'sequence': {'timestamp': '2021-03-29T14:18:25.629+02:00', 'number': 99, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe48'), 'sequence': {'timestamp': '2021-03-29T14:18:28.633+02:00', 'number': 100, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}

# %%
# Defining test parameters
collection_name = "myCollection"
schema = "schema_status"

cursor = filter_by_schema(db, collection_name, schema)

# Checking if the function returned a cursor
if cursor is not None:
    for document in cursor:
        print(document)
else:
    print("No documents found.")
# Out:
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fde6'), 'sequence': {'timestamp': '2021-03-29T14:13:34.249+02:00', 'number': 2, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fde7'), 'sequence': {'timestamp': '2021-03-29T14:13:37.253+02:00', 'number': 3, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fde8'), 'sequence': {'timestamp': '2021-03-29T14:13:40.257+02:00', 'number': 4, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fde9'), 'sequence': {'timestamp': '2021-03-29T14:13:43.261+02:00', 'number': 5, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fdea'), 'sequence': {'timestamp': '2021-03-29T14:13:46.265+02:00', 'number': 6, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fdeb'), 'sequence': {'timestamp': '2021-03-29T14:13:49.268+02:00', 'number': 7, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fdec'), 'sequence': {'timestamp': '2021-03-29T14:13:52.273+02:00', 'number': 8, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fded'), 'sequence': {'timestamp': '2021-03-29T14:13:55.277+02:00', 'number': 9, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fdee'), 'sequence': {'timestamp': '2021-03-29T14:13:58.281+02:00', 'number': 10, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fdef'), 'sequence': {'timestamp': '2021-03-29T14:14:01.285+02:00', 'number': 11, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fdf0'), 'sequence': {'timestamp': '2021-03-29T14:14:04.290+02:00', 'number': 12, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fdf1'), 'sequence': {'timestamp': '2021-03-29T14:14:07.294+02:00', 'number': 13, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fdf2'), 'sequence': {'timestamp': '2021-03-29T14:14:10.297+02:00', 'number': 14, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fdf3'), 'sequence': {'timestamp': '2021-03-29T14:14:13.303+02:00', 'number': 15, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fdf4'), 'sequence': {'timestamp': '2021-03-29T14:14:16.307+02:00', 'number': 16, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fdf5'), 'sequence': {'timestamp': '2021-03-29T14:14:19.309+02:00', 'number': 17, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fd
 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe5e'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:15:40.835+0200', 'number': 7, 'service': 'TomoKISStudio#13503'}, 'payload': {'service': 'TomoKISStudio#13503', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe5f'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:15:45.836+0200', 'number': 8, 'service': 'TomoKISStudio#13503'}, 'payload': {'service': 'TomoKISStudio#13503', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe60'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:18:30.118+0200', 'number': 1, 'service': 'TomoKISStudio#14163'}, 'payload': {'service': 'TomoKISStudio#14163', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe61'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:18:35.130+0200', 'number': 2, 'service': 'TomoKISStudio#14163'}, 'payload': {'service': 'TomoKISStudio#14163', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe62'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:18:40.142+0200', 'number': 3, 'service': 'TomoKISStudio#14163'}, 'payload': {'service': 'TomoKISStudio#14163', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe63'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:21:52.503+0200', 'number': 1, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe64'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:21:57.504+0200', 'number': 2, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe65'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:22:02.507+0200', 'number': 3, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe66'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:22:07.516+0200', 'number': 4, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe67'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:22:12.519+0200', 'number': 5, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe68'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:22:17.742+0200', 'number': 6, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe69'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:22:22.755+0200', 'number': 7, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe6a'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:22:27.771+0200', 'number': 8, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe6b'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:22:32.785+0200', 'number': 9, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe6c'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:22:37.795+0200', 'number': 10, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe6d'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:22:42.802+0200', 'number': 11, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe6e'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:22:47.815+0200', 'number': 12, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe6f'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:22:52.822+0200', 'number': 13, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe70'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:22:57.835+0200', 'number': 14, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe71'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:23:02.856+0200', 'number': 15, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe72'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:23:07.885+0200', 'number': 16, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe73'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:23:12.892+0200', 'number': 17, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe74'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:23:17.908+0200', 'number': 18, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe75'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:23:22.926+0200', 'number': 19, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe76'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:23:27.938+0200', 'number': 20, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe77'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:23:49.177+0200', 'number': 1, 'service': 'TomoKISStudio#15201'}, 'payload': {'service': 'TomoKISStudio#15201', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe78'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:27:59.605+0200', 'number': 1, 'service': 'TomoKISStudio#15995'}, 'payload': {'service': 'TomoKISStudio#15995', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe79'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:46:28.818+0200', 'number': 1, 'service': 'TomoKISStudio#17383'}, 'payload': {'service': 'TomoKISStudio#17383', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe7a'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:55:02.483+0200', 'number': 1, 'service': 'TomoKISStudio#21315'}, 'payload': {'service': 'TomoKISStudio#21315', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# ...
# {'_id': ObjectId('64bfbf3f6aca1b1e26d8572b'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-11T22:14:34.675+0200', 'number': 27, 'service': 'SIMULATOR'}, 'payload': {'service': 'SIMULATOR', 'publishes': ['NI_vortex_control'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3f6aca1b1e26d8572c'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-11T22:14:39.691+0200', 'number': 28, 'service': 'SIMULATOR'}, 'payload': {'service': 'SIMULATOR', 'publishes': ['NI_vortex_control'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3f6aca1b1e26d8572d'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-11T22:14:44.697+0200', 'number': 29, 'service': 'SIMULATOR'}, 'payload': {'service': 'SIMULATOR', 'publishes': ['NI_vortex_control'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3f6aca1b1e26d8572e'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-11T22:14:49.700+0200', 'number': 30, 'service': 'SIMULATOR'}, 'payload': {'service': 'SIMULATOR', 'publishes': ['NI_vortex_control'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3f6aca1b1e26d8572f'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-11T22:14:54.717+0200', 'number': 31, 'service': 'SIMULATOR'}, 'payload': {'service': 'SIMULATOR', 'publishes': ['NI_vortex_control'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3f6aca1b1e26d85730'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-11T22:14:59.720+0200', 'number': 32, 'service': 'SIMULATOR'}, 'payload': {'service': 'SIMULATOR', 'publishes': ['NI_vortex_control'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3f6aca1b1e26d85731'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-11T22:15:04.735+0200', 'number': 33, 'service': 'SIMULATOR'}, 'payload': {'service': 'SIMULATOR', 'publishes': ['NI_vortex_control'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3f6aca1b1e26d85732'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-11T22:15:09.743+0200', 'number': 34, 'service': 'SIMULATOR'}, 'payload': {'service': 'SIMULATOR', 'publishes': ['NI_vortex_control'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3f6aca1b1e26d85733'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-11T22:15:14.747+0200', 'number': 35, 'service': 'SIMULATOR'}, 'payload': {'service': 'SIMULATOR', 'publishes': ['NI_vortex_control'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3f6aca1b1e26d85734'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-11T22:15:19.762+0200', 'number': 36, 'service': 'SIMULATOR'}, 'payload': {'service': 'SIMULATOR', 'publishes': ['NI_vortex_control'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3f6aca1b1e26d85735'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-11T22:15:24.771+0200', 'number': 37, 'service': 'SIMULATOR'}, 'payload': {'service': 'SIMULATOR', 'publishes': ['NI_vortex_control'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3f6aca1b1e26d85736'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:35:43.564+0200', 'number': 1, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3f6aca1b1e26d85737'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:35:48.564+0200', 'number': 2, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3f6aca1b1e26d85738'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:35:53.580+0200', 'number': 3, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3f6aca1b1e26d8573c'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:35:58.587+0200', 'number': 4, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': ['ET-OfflineMode', 'ET_Tomograms'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3f6aca1b1e26d8574a'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:36:03.602+0200', 'number': 5, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': ['ET-OfflineMode', 'ET_Tomograms'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3f6aca1b1e26d8575a'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:36:08.609+0200', 'number': 6, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': ['ET-OfflineMode', 'ET_Tomograms'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3f6aca1b1e26d8576a'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:36:13.613+0200', 'number': 7, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': ['ET-OfflineMode', 'ET_Tomograms'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3f6aca1b1e26d8577a'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:36:18.620+0200', 'number': 8, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': ['ET-OfflineMode', 'ET_Tomograms'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3f6aca1b1e26d85781'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:36:44.136+0200', 'number': 1, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3f6aca1b1e26d85782'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:36:49.147+0200', 'number': 2, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3f6aca1b1e26d85783'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:36:54.162+0200', 'number': 3, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3f6aca1b1e26d85788'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:36:59.165+0200', 'number': 4, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': ['ET-OfflineMode', 'ET_Tomograms'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3f6aca1b1e26d85795'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:37:04.165+0200', 'number': 5, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': ['ET-OfflineMode', 'ET_Tomograms'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3f6aca1b1e26d857a5'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:37:09.180+0200', 'number': 6, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': ['ET-OfflineMode', 'ET_Tomograms'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3f6aca1b1e26d857b5'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:37:14.183+0200', 'number': 7, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': ['ET-OfflineMode', 'ET_Tomograms'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf406aca1b1e26d857c5'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:37:19.188+0200', 'number': 8, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': ['ET-OfflineMode', 'ET_Tomograms'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf406aca1b1e26d857d5'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:37:24.196+0200', 'number': 9, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': ['ET-OfflineMode', 'ET_Tomograms'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf406aca1b1e26d857e5'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:37:29.203+0200', 'number': 10, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': ['ET-OfflineMode', 'ET_Tomograms'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf406aca1b1e26d857f5'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:37:34.214+0200', 'number': 11, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': ['ET-OfflineMode', 'ET_Tomograms'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf406aca1b1e26d85805'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:37:39.224+0200', 'number': 12, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': ['ET-OfflineMode', 'ET_Tomograms'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf406aca1b1e26d85815'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:37:44.239+0200', 'number': 13, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': ['ET-OfflineMode', 'ET_Tomograms'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf406aca1b1e26d85825'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:37:49.253+0200', 'number': 14, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': ['ET-OfflineMode', 'ET_Tomograms'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf406aca1b1e26d85835'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:37:54.267+0200', 'number': 15, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': ['ET-OfflineMode', 'ET_Tomograms'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf406aca1b1e26d85845'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:37:59.269+0200', 'number': 16, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': ['ET-OfflineMode', 'ET_Tomograms'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf406aca1b1e26d85855'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:38:04.273+0200', 'number': 17, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': ['ET-OfflineMode', 'ET_Tomograms'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf406aca1b1e26d85864'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:38:09.281+0200', 'number': 18, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': ['ET-OfflineMode', 'ET_Tomograms'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf406aca1b1e26d85872'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:38:14.294+0200', 'number': 19, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': ['ET-OfflineMode', 'ET_Tomograms'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf406aca1b1e26d85885'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:38:19.298+0200', 'number': 20, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': ['ET-OfflineMode', 'ET_Tomograms'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf406aca1b1e26d85892'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:38:24.305+0200', 'number': 21, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': ['ET-OfflineMode', 'ET_Tomograms'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf406aca1b1e26d858a2'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:38:29.314+0200', 'number': 22, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': ['ET-OfflineMode', 'ET_Tomograms'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf406aca1b1e26d858b2'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:38:34.318+0200', 'number': 23, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': ['ET-OfflineMode', 'ET_Tomograms'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf406aca1b1e26d858bc'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:38:39.331+0200', 'number': 24, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': ['ET-OfflineMode', 'ET_Tomograms'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf406aca1b1e26d858bd'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:38:44.344+0200', 'number': 25, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': ['ET-OfflineMode', 'ET_Tomograms'], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}

# %%
# Defining test parameters
collection_name = "myCollection"
timeout = 20000

cursor = filter_by_timeout(db, collection_name, timeout)

# Checking if the function returned a cursor
if cursor is not None:
    for document in cursor:
        print(document)
else:
    print("No documents found.")
# Out:
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fde6'), 'sequence': {'timestamp': '2021-03-29T14:13:34.249+02:00', 'number': 2, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fde7'), 'sequence': {'timestamp': '2021-03-29T14:13:37.253+02:00', 'number': 3, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fde8'), 'sequence': {'timestamp': '2021-03-29T14:13:40.257+02:00', 'number': 4, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fde9'), 'sequence': {'timestamp': '2021-03-29T14:13:43.261+02:00', 'number': 5, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fdea'), 'sequence': {'timestamp': '2021-03-29T14:13:46.265+02:00', 'number': 6, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fdeb'), 'sequence': {'timestamp': '2021-03-29T14:13:49.268+02:00', 'number': 7, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7f
), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:05:38.208+0200', 'number': 2, 'service': 'TomoKISStudio#11622'}, 'payload': {'service': 'TomoKISStudio#11622', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe4f'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:05:43.219+0200', 'number': 3, 'service': 'TomoKISStudio#11622'}, 'payload': {'service': 'TomoKISStudio#11622', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe50'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:05:48.227+0200', 'number': 4, 'service': 'TomoKISStudio#11622'}, 'payload': {'service': 'TomoKISStudio#11622', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe51'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:05:53.244+0200', 'number': 5, 'service': 'TomoKISStudio#11622'}, 'payload': {'service': 'TomoKISStudio#11622', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe52'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:05:58.254+0200', 'number': 6, 'service': 'TomoKISStudio#11622'}, 'payload': {'service': 'TomoKISStudio#11622', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe53'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:06:03.434+0200', 'number': 7, 'service': 'TomoKISStudio#11622'}, 'payload': {'service': 'TomoKISStudio#11622', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe54'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:06:08.443+0200', 'number': 8, 'service': 'TomoKISStudio#11622'}, 'payload': {'service': 'TomoKISStudio#11622', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe55'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:06:13.453+0200', 'number': 9, 'service': 'TomoKISStudio#11622'}, 'payload': {'service': 'TomoKISStudio#11622', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe56'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:06:18.463+0200', 'number': 10, 'service': 'TomoKISStudio#11622'}, 'payload': {'service': 'TomoKISStudio#11622', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe57'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:06:23.468+0200', 'number': 11, 'service': 'TomoKISStudio#11622'}, 'payload': {'service': 'TomoKISStudio#11622', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe58'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:15:10.426+0200', 'number': 1, 'service': 'TomoKISStudio#13503'}, 'payload': {'service': 'TomoKISStudio#13503', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe59'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:15:15.524+0200', 'number': 2, 'service': 'TomoKISStudio#13503'}, 'payload': {'service': 'TomoKISStudio#13503', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe5a'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:15:20.537+0200', 'number': 3, 'service': 'TomoKISStudio#13503'}, 'payload': {'service': 'TomoKISStudio#13503', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe5b'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:15:25.799+0200', 'number': 4, 'service': 'TomoKISStudio#13503'}, 'payload': {'service': 'TomoKISStudio#13503', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe5c'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:15:30.821+0200', 'number': 5, 'service': 'TomoKISStudio#13503'}, 'payload': {'service': 'TomoKISStudio#13503', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe5d'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:15:35.833+0200', 'number': 6, 'service': 'TomoKISStudio#13503'}, 'payload': {'service': 'TomoKISStudio#13503', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe5e'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:15:40.835+0200', 'number': 7, 'service': 'TomoKISStudio#13503'}, 'payload': {'service': 'TomoKISStudio#13503', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe5f'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:15:45.836+0200', 'number': 8, 'service': 'TomoKISStudio#13503'}, 'payload': {'service': 'TomoKISStudio#13503', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe60'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:18:30.118+0200', 'number': 1, 'service': 'TomoKISStudio#14163'}, 'payload': {'service': 'TomoKISStudio#14163', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe61'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:18:35.130+0200', 'number': 2, 'service': 'TomoKISStudio#14163'}, 'payload': {'service': 'TomoKISStudio#14163', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe62'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:18:40.142+0200', 'number': 3, 'service': 'TomoKISStudio#14163'}, 'payload': {'service': 'TomoKISStudio#14163', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe63'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:21:52.503+0200', 'number': 1, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe64'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:21:57.504+0200', 'number': 2, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe65'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:22:02.507+0200', 'number': 3, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe66'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:22:07.516+0200', 'number': 4, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe67'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:22:12.519+0200', 'number': 5, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe68'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:22:17.742+0200', 'number': 6, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe69'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:22:22.755+0200', 'number': 7, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe6a'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:22:27.771+0200', 'number': 8, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe6b'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:22:32.785+0200', 'number': 9, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe6c'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:22:37.795+0200', 'number': 10, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe6d'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:22:42.802+0200', 'number': 11, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe6e'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:22:47.815+0200', 'number': 12, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe6f'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:22:52.822+0200', 'number': 13, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe70'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:22:57.835+0200', 'number': 14, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe71'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:23:02.856+0200', 'number': 15, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe72'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:23:07.885+0200', 'number': 16, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe73'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:23:12.892+0200', 'number': 17, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe74'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:23:17.908+0200', 'number': 18, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe75'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:23:22.926+0200', 'number': 19, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe76'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:23:27.938+0200', 'number': 20, 'service': 'TomoKISStudio#14819'}, 'payload': {'service': 'TomoKISStudio#14819', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe77'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:23:49.177+0200', 'number': 1, 'service': 'TomoKISStudio#15201'}, 'payload': {'service': 'TomoKISStudio#15201', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe78'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:27:59.605+0200', 'number': 1, 'service': 'TomoKISStudio#15995'}, 'payload': {'service': 'TomoKISStudio#15995', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe79'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:46:28.818+0200', 'number': 1, 'service': 'TomoKISStudio#17383'}, 'payload': {'service': 'TomoKISStudio#17383', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe7a'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-04-10T19:55:02.483+0200', 'number': 1, 'service': 'TomoKISStudio#21315'}, 'payload': {'service': 'TomoKISStudio#21315', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# ...
# {'_id': ObjectId('64bfbf3d6aca1b1e26d850be'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-09T08:46:30.557+0200', 'number': 66, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d850bf'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-09T08:46:35.559+0200', 'number': 67, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d850c0'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-09T08:46:40.561+0200', 'number': 68, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d850c1'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-09T08:46:45.561+0200', 'number': 69, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d850c2'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-09T08:46:50.564+0200', 'number': 70, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d850c3'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-09T08:46:55.564+0200', 'number': 71, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d850c4'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-09T08:47:00.567+0200', 'number': 72, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d850c5'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-09T08:47:05.568+0200', 'number': 73, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d850c6'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-09T08:47:10.571+0200', 'number': 74, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d850c7'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-09T08:47:15.572+0200', 'number': 75, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d850c8'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-09T08:47:20.572+0200', 'number': 76, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d850c9'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-09T08:47:25.575+0200', 'number': 77, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d850ca'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-09T08:47:30.577+0200', 'number': 78, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d850cb'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-09T08:47:35.579+0200', 'number': 79, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d850cc'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-09T08:47:40.580+0200', 'number': 80, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d850cd'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-09T08:47:45.581+0200', 'number': 81, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d850ce'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-09T08:47:50.582+0200', 'number': 82, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d850cf'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-09T08:47:55.583+0200', 'number': 83, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d850d0'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-09T08:48:00.584+0200', 'number': 84, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d850d1'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-09T08:48:05.586+0200', 'number': 85, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d850d2'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-09T08:48:10.588+0200', 'number': 86, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d850d3'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-09T08:48:15.590+0200', 'number': 87, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d850d4'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-09T08:48:20.592+0200', 'number': 88, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d850d5'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-09T08:48:25.593+0200', 'number': 89, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d850d6'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-09T08:48:30.595+0200', 'number': 90, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d850d7'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-09T08:48:35.598+0200', 'number': 91, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d850d8'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-09T08:48:40.600+0200', 'number': 92, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d850d9'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-09T08:48:45.602+0200', 'number': 93, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d850da'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-09T08:48:50.604+0200', 'number': 94, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d850db'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-09T08:48:55.605+0200', 'number': 95, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d850dc'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-09T08:49:00.606+0200', 'number': 96, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d850dd'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-09T08:49:05.607+0200', 'number': 97, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d850de'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-09T08:49:10.609+0200', 'number': 98, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d850df'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-09T08:49:15.610+0200', 'number': 99, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d850e0'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-09T08:49:20.611+0200', 'number': 100, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d851c5'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-11T21:37:31.821+0200', 'number': 1, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d851c6'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-11T21:37:36.831+0200', 'number': 2, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d851c7'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-11T21:37:41.836+0200', 'number': 3, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3d6aca1b1e26d851c8'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-11T21:37:46.840+0200', 'number': 4, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3e6aca1b1e26d85386'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-11T22:10:44.449+0200', 'number': 1, 'service': 'SIMULATOR'}, 'payload': {'service': 'SIMULATOR', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3f6aca1b1e26d85522'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-11T22:12:24.430+0200', 'number': 1, 'service': 'SIMULATOR'}, 'payload': {'service': 'SIMULATOR', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3f6aca1b1e26d85736'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:35:43.564+0200', 'number': 1, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3f6aca1b1e26d85737'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:35:48.564+0200', 'number': 2, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3f6aca1b1e26d85738'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:35:53.580+0200', 'number': 3, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3f6aca1b1e26d85781'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:36:44.136+0200', 'number': 1, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3f6aca1b1e26d85782'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:36:49.147+0200', 'number': 2, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}
# {'_id': ObjectId('64bfbf3f6aca1b1e26d85783'), 'sequence': {'schema': 'schema_status', 'channel': 'status', 'timestamp': '2021-07-12T08:36:54.162+0200', 'number': 3, 'service': 'TomoKISStudio#RadekLaptop'}, 'payload': {'service': 'TomoKISStudio#RadekLaptop', 'publishes': [], 'subscribes': [], 'next_alive_interval': 5000, 'timeout': 25000}}

# %%
cursor = filter_by_subscribes(db, collection_name, subscribes)

# Checking if the function returned a cursor
if cursor is not None:
    for document in cursor:
        print(document)
else:
    print("No documents found.")
# Out:
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7f
 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe29'), 'sequence': {'timestamp': '2021-03-29T14:16:55.511+02:00', 'number': 69, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe2a'), 'sequence': {'timestamp': '2021-03-29T14:16:58.513+02:00', 'number': 70, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe2b'), 'sequence': {'timestamp': '2021-03-29T14:17:01.518+02:00', 'number': 71, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe2c'), 'sequence': {'timestamp': '2021-03-29T14:17:04.521+02:00', 'number': 72, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe2d'), 'sequence': {'timestamp': '2021-03-29T14:17:07.525+02:00', 'number': 73, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe2e'), 'sequence': {'timestamp': '2021-03-29T14:17:10.529+02:00', 'number': 74, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe2f'), 'sequence': {'timestamp': '2021-03-29T14:17:13.533+02:00', 'number': 75, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe30'), 'sequence': {'timestamp': '2021-03-29T14:17:16.537+02:00', 'number': 76, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe31'), 'sequence': {'timestamp': '2021-03-29T14:17:19.540+02:00', 'number': 77, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe32'), 'sequence': {'timestamp': '2021-03-29T14:17:22.545+02:00', 'number': 78, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe33'), 'sequence': {'timestamp': '2021-03-29T14:17:25.549+02:00', 'number': 79, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe34'), 'sequence': {'timestamp': '2021-03-29T14:17:28.553+02:00', 'number': 80, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe35'), 'sequence': {'timestamp': '2021-03-29T14:17:31.557+02:00', 'number': 81, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe36'), 'sequence': {'timestamp': '2021-03-29T14:17:34.561+02:00', 'number': 82, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe37'), 'sequence': {'timestamp': '2021-03-29T14:17:37.565+02:00', 'number': 83, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe38'), 'sequence': {'timestamp': '2021-03-29T14:17:40.569+02:00', 'number': 84, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe39'), 'sequence': {'timestamp': '2021-03-29T14:17:43.573+02:00', 'number': 85, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe3a'), 'sequence': {'timestamp': '2021-03-29T14:17:46.577+02:00', 'number': 86, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe3b'), 'sequence': {'timestamp': '2021-03-29T14:17:49.580+02:00', 'number': 87, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe3c'), 'sequence': {'timestamp': '2021-03-29T14:17:52.586+02:00', 'number': 88, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe3d'), 'sequence': {'timestamp': '2021-03-29T14:17:55.590+02:00', 'number': 89, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe3e'), 'sequence': {'timestamp': '2021-03-29T14:17:58.593+02:00', 'number': 90, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe3f'), 'sequence': {'timestamp': '2021-03-29T14:18:01.597+02:00', 'number': 91, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe40'), 'sequence': {'timestamp': '2021-03-29T14:18:04.601+02:00', 'number': 92, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe41'), 'sequence': {'timestamp': '2021-03-29T14:18:07.605+02:00', 'number': 93, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe42'), 'sequence': {'timestamp': '2021-03-29T14:18:10.609+02:00', 'number': 94, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe43'), 'sequence': {'timestamp': '2021-03-29T14:18:13.614+02:00', 'number': 95, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe44'), 'sequence': {'timestamp': '2021-03-29T14:18:16.618+02:00', 'number': 96, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe45'), 'sequence': {'timestamp': '2021-03-29T14:18:19.622+02:00', 'number': 97, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe46'), 'sequence': {'timestamp': '2021-03-29T14:18:22.625+02:00', 'number': 98, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe47'), 'sequence': {'timestamp': '2021-03-29T14:18:25.629+02:00', 'number': 99, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7fe48'), 'sequence': {'timestamp': '2021-03-29T14:18:28.633+02:00', 'number': 100, 'channel': 'status', 'service': 'mediator', 'schema': 'schema_status'}, 'payload': {'service': 'mediator', 'publishes': [], 'subscribes': ['status'], 'next_alive_interval': 3000, 'timeout': 20000}}

# %%
cursor = filter_by_next_alive_interval(db, collection_name, next_alive_interval)

# Checking if the function returned a cursor
if cursor is not None:
    for document in cursor:
        print(document)
else:
    print("No documents found.")
# Out:
# {'_id': ObjectId('64bfbe9a6aca1b1e26d7f
# This function returns all distinct channels present in the documents of the specified collection. It uses MongoDB's aggregation operation to group the documents by the "sequence.channel" key and return each distinct channel value.
#
#
# get_available_services(db, collection_name):
#
# This function is similar to the get_available_channels function, but groups documents by service instead of channel.
#
#
# get_oldest_and_newest_date_by_channel(db, collection_name, channel):
#
# This function returns the earliest and latest dates for a specific channel.
#
#
# get_oldest_and_newest_date_by_schema(db, collection_name, schema):
#
# This function is similar to get_oldest_and_newest_date_by_channel, but filters documents by schema instead of channel.
#
#
# get_messages_by_service(db, collection_name, service):
#
# This function returns information about all channels for a specific service. It groups documents by channel, counts the number of records, and finds the oldest and newest dates for each channel.
#
#
# get_message_fields(db, collection_name, channel, service):
#
# This function returns information about the fields in the document payload for a specific channel and service. It returns the name of each field, plus a placeholder for the field type, size, and data, which you'll need to fill in based on the schema and documents.

# %%
def get_available_channels(db, collection_name):
    # Groups documents by the key "sequence.channel" and returns the result
    pipeline = [
        {"$group": {"_id": "$sequence.channel"}}
    ]
    # Uses the aggregation operation to run the pipeline on the database
    result = db[collection_name].aggregate(pipeline)
    # Creates a list of all returned channels
    channels = [doc["_id"] for doc in result]
    return channels


def get_available_services(db, collection_name):
    # Groups documents by the key "sequence.service" and returns the result
    pipeline = [
        {"$group": {"_id": "$sequence.service"}}
    ]
    # Uses the aggregation operation to run the pipeline on the database
    result = db[collection_name].aggregate(pipeline)
    # Creates a list of all returned services
    services = [doc["_id"] for doc in result]
    return services

def get_oldest_and_newest_date_by_channel(db, collection_name, channel):
    # Filters documents by the specified channel and groups them to get the oldest and newest dates
    pipeline = [
        {"$match": {"sequence.channel": channel}},
        {"$group": {"_id": None, "oldest": {"$min": "$sequence.timestamp"}, "newest": {"$max": "$sequence.timestamp"}}}
    ]
    # Uses the aggregation operation to run the pipeline on the database
    result = db[collection_name].aggregate(pipeline)
    # Get the first document returned
    document = next(result, None)
    if document:
        oldest_date = document["oldest"]
        newest_date = document["newest"]
        return oldest_date, newest_date
    else:
        return None, None
    
def get_oldest_and_newest_date_by_schema(db, collection_name, schema):
    # Filters the documents by the specified schema and groups them to get the oldest and newest dates
    pipeline = [
        {"$match": {"sequence.schema": schema}},
        {"$group": {"_id": None, "oldest": {"$min": "$sequence.timestamp"}, "newest": {"$max": "$sequence.timestamp"}}}
    ]
    # Uses the aggregation operation to run the pipeline on the database
    result = db[collection_name].aggregate(pipeline)
    # Get the first document returned
    document = next(result, None)
    if document:
        oldest_date = document["oldest"]
        newest_date = document["newest"]
        return oldest_date, newest_date
    else:
        return None, None
    
def get_messages_by_service(db, collection_name, service):
    # Filters documents by specified service, groups them by channel, and returns information about each group
    pipeline = [
        {"$match": {"sequence.service": service}},
        {"$group": {"_id": "$sequence.channel", "schema": {"$first": "$sequence.schema"}, "records": {"$sum": 1}, "since": {"$min": "$sequence.timestamp"}, "until": {"$max": "$sequence.timestamp"}}},
        {"$project": {"_id": 0, "channel": "$_id", "schema": 1, "records": 1, "since": 1, "until": 1}}
    ]
    # Uses the aggregation operation to run the pipeline on the database
    result = db[collection_name].aggregate(pipeline)
    # Creates a list of all returned messages
    messages = []
    for doc in result:
        message = {
            "channel": doc["channel"],
            "schema": doc["schema"],
            "records": doc["records"],
            "since": doc["since"],
            "until": doc["until"]
        }
        messages.append(message)
    return messages

def get_message_fields(db, collection_name, channel, service):
    # Filters the documents by the specified channel and service, extracts the fields from the payload and returns information about each field
    pipeline = [
        {"$match": {"sequence.channel": channel, "sequence.service": service}},
        {"$limit": 1},
        {"$project": {"fields": {"$objectToArray": "$payload"}}},
        {"$unwind": "$fields"},
        {"$group": {"_id": None, "fields": {"$push": "$fields.k"}}},
        {"$project": {"_id": 0, "fields": 1}}
    ]
    # Uses the aggregation operation to run the pipeline on the database
    result = db[collection_name].aggregate(pipeline)
    # Get the first document returned
    document = next(result, None)
    if document:
        fields = document["fields"]
        num_fields = len(fields)
        data = []
        for i, field in enumerate(fields):
            field_data = {
                "field": field,
                "type_of_field": "",  # needs to be filled in based on the schema
                "size": 0,  # needs to be filled in based on the schema
                "data": []  # needs to be filled in based on the documents
            }
            data.append({str(i): field_data})
        return {
            "status": "OK",
            "service": service,
            "channel": channel,
            "schema": "",  # Schema needs to be filled
            "since": "",  # The oldest date needs to be filled in based on the documents
            "to": "",  # The newest date needs to be filled in based on the documents
            "fields": num_fields,
            "size": num_fields,
            "data": data
        }
    else:
        return None

# %%
# Testing the function get_available_channels
channels = get_available_channels(db, "myCollection")
print("Available Channels:")
print(channels)

# Testing the function get_available_services
services = get_available_services(db, "myCollection")
print("Available Services:")
print(services)
# Out:
# Available Channels:
# ['ET_Tomograms', 'log', 'DateChannel', 'NI_vortex_control', 'NI_vortex_measurement', 'status', 'ET-OfflineMode', 'TimeChannel', 'CzwarteczekChannel', 'PiateczekChannel']
# Available Services:
# ['mediator', 'TomoKISStudio#GameBoard', 'TomoKISStudio#15201', 'TomoKISStudio#2853', 'TomoKISStudio#17797', 'TomoKISStudio#10629', 'TomoKISStudio#PawelGameBoard', 'TomoKISStudio#11622', 'TomoKISStudio#9346', 'TomoKISStudio#21315', 'TomoKISStudio#16216', 'TomoKISStudio#17500', 'TomoKISStudio#17383', 'SIMULATOR', 'TomoKISStudio#PLATOMK4', 'TomoKISStudio#14819', 'Zegarynka', 'TomoKISStudio#18192', 'TomoKISStudio#8406', 'TomoKISStudio#775', 'NI_CYKLON', 'TomoKISStudio#20143', 'PiateczekDetector', 'TomoKISStudio#RadekLaptop', 'Kangur', 'TomoKISStudio#14163', 'TomoKISStudio#PLATOM4', 'TomoKISStudio#9930', 'TomoKISStudio#15995', 'TomoKISStudio#18460', 'CzwarteczekDetector', 'TomoKISStudio#13503', 'RandomizerKanalowService']

# %%
# Testing the function get_oldest_and_newest_date_by_channel
channel = "NI_vortex_measurement"
oldest_date, newest_date = get_oldest_and_newest_date_by_channel(db, "myCollection", channel)
print(f"Channel: {channel}")
print(f"Oldest Date: {oldest_date}")
print(f"Newest Date: {newest_date}")

# Testing the function get_oldest_and_newest_date_by_schema
schema = "NI_vortex_measurement"
oldest_date, newest_date = get_oldest_and_newest_date_by_schema(db, "myCollection", schema)
print(f"Schema: {schema}")
print(f"Oldest Date: {oldest_date}")
print(f"Newest Date: {newest_date}")
# Out:
# Channel: NI_vortex_measurement
# Oldest Date: 2021-06-21T11:25:13.803+0200
# Newest Date: 2021-07-11T22:09:54.007+0200
# Schema: NI_vortex_measurement
# Oldest Date: 2021-06-21T11:25:13.803+0200
# Newest Date: 2021-07-11T22:09:54.007+0200

# %%
# Testing the function get_messages_by_service
service = "NI_CYKLON"
messages = get_messages_by_service(db, "myCollection", service)
print(f"Messages sent by service '{service}':")
print(messages)
# Out:
# Messages sent by service 'NI_CYKLON':
# [{'channel': 'status', 'schema': 'schema_status', 'records': 314, 'since': '2021-06-21T11:21:53.470+0200', 'until': '2021-07-11T22:09:53.929+0200'}, {'channel': 'NI_vortex_measurement', 'schema': 'NI_vortex_measurement', 'records': 270, 'since': '2021-06-21T11:25:13.803+0200', 'until': '2021-07-11T22:09:54.007+0200'}]

# %%
# Testing the function get_message_fields
channel = "NI_vortex_control"
service = "TomoKISStudio#15995"
fields_info = get_message_fields(db, "myCollection", channel, service)
print("Message Fields:")
print(fields_info)
# Out:
# Message Fields:
# None

# %% [markdown]
# This class is used to represent a user's configuration, including an IP address, a port, some filters, and the location of a logger. Configuration information can be saved to a JSON file and loaded from a JSON file.

# %%
import json

# Define the class UserConfig
class UserConfig:
    def __init__(self, ip_address, port, filters, logger_location):
        self.ip_address = ip_address
        self.port = port
        self.filters = filters
        self.logger_location = logger_location

    # Method to save user configuration to a JSON file
    def save(self, filename):
        with open(filename, 'w') as f:  # Open file in recording mode
            # Use json module's dump method to write configuration to file
            # self.__dict__ is a dictionary that contains the properties of the class instance
            json.dump(self.__dict__, f)  

    # Class method for loading user configuration from a JSON file
    @classmethod
    def load(cls, filename):
        with open(filename, 'r') as f:  # Open file in read mode
            config = json.load(f)  # Load the content of the JSON file into a dictionary
        return cls(**config)

# %%
# Create a new configuration
config = UserConfig('127.0.0.1', 8000, {"channel": "ET_Tomograms", "service": "TomoKISStudio#2853"}, 'app.log')

# Save the configuration to a file
config.save('user_config.json')

# Load configuration from a file
loaded_config = UserConfig.load('user_config.json')
print(loaded_config.ip_address)  # Outputs: 127.0.0.1
# Out:
# 127.0.0.1

# %% [markdown]
# Python script that creates a GUI (Grafical User Interface) for filtering and visualizing data from a MongoDB collection. Here are the details of the script's main components:
#
# Auxiliary functions: Functions that assist in reading and writing the JSON configuration file, connecting to the MongoDB database, initializing the log and manipulating data.
#
# GUI-specific functions: Functions that perform specific actions when buttons are pressed in the GUI. This includes filtering data based on input values, obtaining channels, services, oldest and newest dates, messages by service, message fields, and plotting graphs.
#
# create_gui() function: The main function that creates the GUI using the tkinter package. It creates labels, input fields, buttons, and a text area to display the results.
#
# Connection to MongoDB database: The script connects to MongoDB using the IP address and port provided in the JSON configuration file.
#
# Exception Handling: The script also has exception handling to deal with  possible errors during execution.
#
# Settings: The script reads a configuration file at the beginning to determine the database connection parameters, filters to apply, and the log file. If the configuration file does not exist, it will create one with default values.
#
# Graph Plotting: Using the matplotlib library, this script is capable of plotting graphs with the filtered data from MongoDB.

# %%
import tkinter as tk
from pymongo import MongoClient
import logging
import json
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
from tkinter import messagebox, Scrollbar, Canvas

# Function to retrieve MongoDB payload data
def get_payload_data(cursor):
    data = []
    for document in cursor:
        if "payload" in document:
            payload = document["payload"]
            if "image" in payload:
                image = payload["image"]
                if "data" in image:
                    item = {
                        "timestamp": document["sequence"]["timestamp"],
                        "data": image["data"][0]
                    }
                    data.append(item)
    return data

# Function to start logging
def init_logging(log_file):
    logging.basicConfig(filename=log_file, level=logging.ERROR,
                        format='%(asctime)s - %(levelname)s - %(message)s')
    
# Function to load the configuration file
def load_config(config_file):
    with open(config_file, 'r') as f:
        config = json.load(f)
    return config

# Function to save the configuration file
def save_config(config, config_file):
    with open(config_file, 'w') as f:
        json.dump(config, f, indent=4)

# Main function to create the GUI
def create_gui(db, collection_name):

    # Auxiliary functions
    def execute_filters():
        try:
            channel = channel_entry.get()
            service = service_entry.get()
            schema = schema_entry.get()
            publishes = publishes_entry.get().split(",") if publishes_entry.get() else []
            subscribes = subscribes_entry.get().split(",") if subscribes_entry.get() else []
            next_alive_interval = int(next_alive_interval_entry.get()) if next_alive_interval_entry.get() else None

            # create filter
            filters = {}
            if channel:
                filters["sequence.channel"] = channel
            if service:
                filters["sequence.service"] = service
            if schema:
                filters["sequence.schema"] = schema
            if publishes:
                filters["payload.publishes"] = {"$in": publishes}
            if subscribes:
                filters["payload.subscribes"] = {"$in": subscribes}
            if next_alive_interval is not None:
                filters["payload.next_alive_interval"] = next_alive_interval
            
            cursor = db[collection_name].find(filters)

            # Output the results
            results_text.delete('1.0', tk.END)
            results_text.insert(tk.END, "Filtered Data:\n")
            for document in cursor:
                results_text.insert(tk.END, str(document) + "\n")
            results_text.insert(tk.END, "End of results.")
        
            # Save user's filter values
            config['filters'] = {
                'channel': channel,
                'service': service,
                'schema': schema,
                'publishes': publishes,
                'subscribes': subscribes,
                'next_alive_interval': next_alive_interval
            }
            save_config(config, config_file)

        except Exception as e:
            error_message = str(e)
            messagebox.showerror("Error", error_message)
            logging.error(f"Error executing filters: {error_message}")
                
    def execute_get_channels():
        try:
            results_text.delete('1.0', tk.END)  # New line to clear the text field
            channels = get_available_channels(db, collection_name)
            results_text.insert(tk.END, f"Channels: {channels}\n")
        except Exception as e:
            error_message = str(e)
            messagebox.showerror("Error", str(e))
            logging.error(f"Error getting channels: {error_message}")

    def execute_get_services():
        try:
            results_text.delete('1.0', tk.END)  # New line to clear the text field
            services = get_available_services(db, collection_name)
            results_text.insert(tk.END, f"Services: {services}\n")
        except Exception as e:
            error_message = str(e)
            messagebox.showerror("Error", str(e))
            logging.error(f"Error getting services: {error_message}")

    def execute_get_oldest_and_newest_date_by_channel():
        try:
            results_text.delete('1.0', tk.END)  # New line to clear the text field
            channel = channel_entry.get()
            oldest_date, newest_date = get_oldest_and_newest_date_by_channel(db, collection_name, channel)
            results_text.insert(tk.END, f"For channel '{channel}', oldest date: {oldest_date}, newest date: {newest_date}\n")
        except Exception as e:
            error_message = str(e)
            messagebox.showerror("Error", str(e))
            logging.error(f"Error getting oldest and newest date by channel: {error_message}")

    def execute_get_oldest_and_newest_date_by_schema():
        try:
            results_text.delete('1.0', tk.END)  # New line to clear the text field
            schema = schema_entry.get()
            oldest_date, newest_date = get_oldest_and_newest_date_by_schema(db, collection_name, schema)
            results_text.insert(tk.END, f"For schema '{schema}', oldest date: {oldest_date}, newest date: {newest_date}\n")
        except Exception as e:
            error_message = str(e)
            messagebox.showerror("Error", str(e))
            logging.error(f"Error getting oldest and newest date by schema: {error_message}")

    def execute_get_messages_by_service():
        try:
            results_text.delete('1.0', tk.END)  # New line to clear the text field
            service = service_entry.get()
            messages = get_messages_by_service(db, collection_name, service)
            results_text.insert(tk.END, f"Messages by service '{service}': {messages}\n")
        except Exception as e:
            error_message = str(e)
            messagebox.showerror("Error", str(e))
            logging.error(f"Error getting messages by service: {error_message}")

    def execute_get_message_fields():
        try:
            results_text.delete('1.0', tk.END)  # New line to clear the text field
            channel = channel_entry.get()
            service = service_entry.get()
            message_fields = get_message_fields(db, collection_name, channel, service)
            results_text.insert(tk.END, f"Message fields for channel '{channel}' and service '{service}': {message_fields}\n")
        except Exception as e:
            error_message = str(e)
            messagebox.showerror("Error", str(e))
            logging.error(f"Error getting messages by fields: {error_message}")
    
    def plot_graph():
        try:
            # Gets values from input widgets
            channel = channel_entry.get()
            service = service_entry.get()
            time0 = start_time
            time1 = end_time

            cursor = filter_by_channel_and_service(db, 'myCollection', channel, service)

            data = get_payload_data(cursor)

            df = pd.DataFrame(data)
            df['data_0'] = df['data'].apply(lambda x: x[0] if len(x) > 0 else None)
            df['data_1'] = df['data'].apply(lambda x: x[1] if len(x) > 1 else None)

            df = df.dropna(subset=['data_0', 'data_1'])

            fig = Figure(figsize=(10, 5))
            a = fig.add_subplot(111)

            a.plot(df['timestamp'], df['data_0'], label='first position of data row by time')
            a.plot(df['timestamp'], df['data_1'], label='second position of data row by time')

            a.set_title('Data over time')
            a.set_ylabel('Value')
            a.set_xlabel('Timestamp')
            a.legend(loc='best')
            a.text(0,0.07,"start: " + time0)
            a.text(0,0.06,"end: " + time1)

            # Create a new Frame for matplotlib figure
            plot_frame = tk.Frame(frame)
            plot_frame.grid(row=14, column=0, columnspan=2)

            # Create tkinter widget for matplotlib plot
            canvas = FigureCanvasTkAgg(fig, master=plot_frame) 
            canvas.draw()
            canvas.get_tk_widget().pack()

        except Exception as e:
            messagebox.showerror("Error", str(e))

     # GUI creation
    root = tk.Tk()
    root.title("Data Filtering Tool")
    
    # Creates the main Frame that will host the Canvas and the Scrollbar
    main_frame = tk.Frame(root)
    main_frame.pack(fill=tk.BOTH, expand=1)
    
    # Creates the Canvas
    canvas = tk.Canvas(main_frame)
    canvas.pack(side=tk.LEFT, fill=tk.BOTH, expand=1)
    
    # Creates the Scrollbar
    scrollbar = tk.Scrollbar(main_frame, orient=tk.VERTICAL, command=canvas.yview)
    scrollbar.pack(side=tk.RIGHT, fill=tk.Y)
    
    # Add the frame inside the canvas
    frame = tk.Frame(canvas)
    
    # Add scrollbar to canvas
    canvas.configure(yscrollcommand=scrollbar.set)
    
    # Add the frame to the canvas window
    canvas.create_window((0,0), window=frame, anchor='nw')
    
    # Update canvas scrolling region when frame size changes
    frame.bind('<Configure>', lambda e: canvas.configure(scrollregion=canvas.bbox('all')))

    tk.Label(frame, text="Channel:").grid(row=0, column=0)
    channel_entry = tk.Entry(frame)
    channel_entry.grid(row=0, column=1)

    tk.Label(frame, text="Service:").grid(row=1, column=0)
    service_entry = tk.Entry(frame)
    service_entry.grid(row=1, column=1)

    tk.Label(frame, text="Schema:").grid(row=2, column=0)
    schema_entry = tk.Entry(frame)
    schema_entry.grid(row=2, column=1)

    tk.Label(frame, text="Publishes (comma-separated):").grid(row=3, column=0)
    publishes_entry = tk.Entry(frame)
    publishes_entry.grid(row=3, column=1)

    tk.Label(frame, text="Subscribes (comma-separated):").grid(row=4, column=0)
    subscribes_entry = tk.Entry(frame)
    subscribes_entry.grid(row=4, column=1)

    tk.Label(frame, text="Next alive interval:").grid(row=5, column=0)
    next_alive_interval_entry = tk.Entry(frame)
    next_alive_interval_entry.grid(row=5, column=1)

    filter_button = tk.Button(frame, text="Filter", command=execute_filters)
    filter_button.grid(row=6, column=0, columnspan=2)

    plot_button = tk.Button(frame, text="Plot Graph", command=plot_graph)
    plot_button.grid(row=15, column=0, columnspan=2)

    results_text = tk.Text(frame)
    results_text.grid(row=7, column=0, columnspan=2)

    # Additional buttons for functions
    get_channels_button = tk.Button(frame, text="Get Channels", command=execute_get_channels)
    get_channels_button.grid(row=8, column=0, columnspan=2)
        
    get_services_button = tk.Button(frame, text="Get Services", command=execute_get_services)
    get_services_button.grid(row=9, column=0, columnspan=2)

    get_oldest_and_newest_date_by_channel_button = tk.Button(frame, text="Get Oldest and Newest Date by Channel", command=execute_get_oldest_and_newest_date_by_channel)
    get_oldest_and_newest_date_by_channel_button.grid(row=10, column=0, columnspan=2)
        
    get_oldest_and_newest_date_by_schema_button = tk.Button(frame, text="Get Oldest and Newest Date by Schema", command=execute_get_oldest_and_newest_date_by_schema)
    get_oldest_and_newest_date_by_schema_button.grid(row=11, column=0, columnspan=2)

    get_messages_by_service_button = tk.Button(frame, text="Get Messages by Service", command=execute_get_messages_by_service)
    get_messages_by_service_button.grid(row=12, column=0, columnspan=2)

    get_message_fields_button = tk.Button(frame, text="Get Message Fields", command=execute_get_message_fields)
    get_message_fields_button.grid(row=13, column=0, columnspan=2)

    frame.update_idletasks()

# Configure the canvas scroll area to match the frame size
    canvas.configure(scrollregion=canvas.bbox('all'))

    root.mainloop()

config_file = 'config.json'

# Load user config
try:
    config = load_config(config_file)
except FileNotFoundError:
    config = {
        'db_ip': 'localhost',
        'db_port': 27017,
        'filters': {},
        'log_file': 'app.log'
    }

init_logging(config['log_file'])
init_logging('app.log')

# Connecting to MongoDB Database
db = get_db_connection('localhost', 27017, 'myDatabase')

# Calling the function to create the UI
create_gui(db, "myCollection")
# Out:
# Query: {'sequence.channel': 'ET_Tomograms', 'sequence.service': 'TomoKISStudio#2853'}
